# %%
#Spotify Credentials Load
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials

cid = ""  # Client ID
secret = ""  # Client Secret
username = ""  # Your Spotify username

scope = "user-library-read playlist-modify-public playlist-read-private"

redirect_uri = "http://localhost:8888/callback"

client_credentials_manager = SpotifyClientCredentials(
    client_id=cid, client_secret=secret
)

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

token = util.prompt_for_user_token(
    username,
    scope,
    client_id=cid,
    client_secret=secret,
    redirect_uri="http://localhost:8888/callback",
)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)

# %%
#Fetching data from public playlist of 'happy' songs
import pandas as pd
sourcePlaylistID = 'https://open.spotify.com/playlist/37i9dQZF1DWSf2RDTDayIx?si=fff3c71d81b54594'
sourcePlaylist = sp.playlist(sourcePlaylistID)
tracks = sourcePlaylist["tracks"];
songs = tracks["items"];

track_ids = []
track_names = []

for i in range(0, len(songs)):
    if songs[i]['track']['id'] != None: # Removes the local tracks in your playlist if there is any
        track_ids.append(songs[i]['track']['id'])
        track_names.append(songs[i]['track']['name'])

features = []
for i in range(0, len(track_ids)):
    audio_features = sp.audio_features(track_ids[i])
    track_info = sp.track(track_ids[i])
    
    for track in audio_features:
        if track is None:
            print(track)
            features.append({
                'song_name': track_info['name'],  # Add the song name
                'artists': ', '.join([artist['name'] for artist in track_info['artists']]),  # Add the artists as a comma-separated string
                'danceability': 0,
                'energy': 0,
                'key': 0,
                'loudness': 0,
                'mode': 0,
                'speechiness': 0,
                'acousticness': 0,
                'instrumentalness': 0,
                'liveness': 0,
                'valence': 0,
                'tempo': 0,
                'type': 'audio_features',
                'id': '00000',
                'uri': 'spotify:track:0',
                'track_href': 'https://api.spotify.com/',
                'analysis_url': 'https://api.spotify.com/',
                'duration_ms': 0,
                'time_signature': 0
            })
        else:
            features.append({
                'song_name': track_info['name'],  # Add the song name
                'artists': ', '.join([artist['name'] for artist in track_info['artists']]),  # Add the artists as a comma-separated string
                **track  # Include the audio features
            })
      

happy_df = pd.DataFrame(features, index = track_names)
happy_df['Mood Label'] = 'happy'
happy_df.head()
# Out:
#                                                                                  song_name  \
# Cold Heart - PNAU Remix                                            Cold Heart - PNAU Remix
# Little Things x Gypsy Woman - L BEATS MASHUP  Little Things x Gypsy Woman - L BEATS MASHUP
# Deep Down (feat. Never Dull)                                  Deep Down (feat. Never Dull)
# Words (feat. Zara Larsson)                                      Words (feat. Zara Larsson)
# Relax My Eyes                                                                Relax My Eyes
#
#                                                                               artists  \
# Cold Heart - PNAU Remix                                    Elton John, Dua Lipa, PNAU
# Little Things x Gypsy Woman - L BEATS MASHUP                              Jorja Smith
# Deep Down (feat. Never Dull)                  Alok, Ella Eyre, Kenny Dope, Never Dull
# ...

# %%
#Exporting dataframe to csv
happy_df.to_csv('happy.csv',index=False)

# %%
#Fetching data from public playlist of 'sad' songs

sourcePlaylistID = 'https://open.spotify.com/playlist/37i9dQZF1DX3YSRoSdA634'
sourcePlaylist = sp.playlist(sourcePlaylistID)
tracks = sourcePlaylist["tracks"];
songs = tracks["items"];

track_ids = []
track_names = []

for i in range(0, len(songs)):
    if songs[i]['track']['id'] != None: # Removes the local tracks in your playlist if there is any
        track_ids.append(songs[i]['track']['id'])
        track_names.append(songs[i]['track']['name'])

features = []
for i in range(0, len(track_ids)):
    audio_features = sp.audio_features(track_ids[i])
    track_info = sp.track(track_ids[i])
    
    for track in audio_features:
        if track is None:
            print(track)
            features.append({
                'song_name': track_info['name'],  # Add the song name
                'artists': ', '.join([artist['name'] for artist in track_info['artists']]),  # Add the artists as a comma-separated string
                'danceability': 0,
                'energy': 0,
                'key': 0,
                'loudness': 0,
                'mode': 0,
                'speechiness': 0,
                'acousticness': 0,
                'instrumentalness': 0,
                'liveness': 0,
                'valence': 0,
                'tempo': 0,
                'type': 'audio_features',
                'id': '00000',
                'uri': 'spotify:track:0',
                'track_href': 'https://api.spotify.com/',
                'analysis_url': 'https://api.spotify.com/',
                'duration_ms': 0,
                'time_signature': 0
            })
        else:
            features.append({
                'song_name': track_info['name'],  # Add the song name
                'artists': ', '.join([artist['name'] for artist in track_info['artists']]),  # Add the artists as a comma-separated string
                **track  # Include the audio features
            })

      

sad_df = pd.DataFrame(features, index = track_names)
sad_df['Mood Label'] = 'sad'
sad_df.head()
# Out:
#                                  song_name                artists  \
# august                              august           Taylor Swift
# Another Love                  Another Love              Tom Odell
# People                              People               Libianca
# lovely (with Khalid)  lovely (with Khalid)  Billie Eilish, Khalid
# When I Was Your Man    When I Was Your Man             Bruno Mars
#
#                       danceability  energy  key  loudness  mode  speechiness  \
# august                       0.532   0.623    5    -9.208     1       0.0331
# Another Love                 0.445   0.537    4    -8.532     0       0.0400
# People                       0.573   0.422   10    -7.621     0       0.0678
# lovely (with Khalid)         0.351   0.296    4   -10.109     0       0.0333
# When I Was Your Man          0.612   0.280    0    -8.648     1       0.0434
#
#                       acousticness  instrumentalness  ...  valence    tempo  \
# ...

# %%
#Exporting dataframe to csv
sad_df.to_csv('sad.csv',index=False)

# %%
#Fetching data from public playlist of 'relaxing' songs

sourcePlaylistID = 'https://open.spotify.com/playlist/37i9dQZF1DX4sWSpwq3LiO'
sourcePlaylist = sp.playlist(sourcePlaylistID)
tracks = sourcePlaylist["tracks"];
songs = tracks["items"];

track_ids = []
track_names = []

for i in range(0, len(songs)):
    if songs[i]['track']['id'] != None: # Removes the local tracks in your playlist if there is any
        track_ids.append(songs[i]['track']['id'])
        track_names.append(songs[i]['track']['name'])

features = []
for i in range(0, len(track_ids)):
    audio_features = sp.audio_features(track_ids[i])
    track_info = sp.track(track_ids[i])
    
    for track in audio_features:
        if track is None:
            print(track)
            features.append({
                'song_name': track_info['name'],  # Add the song name
                'artists': ', '.join([artist['name'] for artist in track_info['artists']]),  # Add the artists as a comma-separated string
                'danceability': 0,
                'energy': 0,
                'key': 0,
                'loudness': 0,
                'mode': 0,
                'speechiness': 0,
                'acousticness': 0,
                'instrumentalness': 0,
                'liveness': 0,
                'valence': 0,
                'tempo': 0,
                'type': 'audio_features',
                'id': '00000',
                'uri': 'spotify:track:0',
                'track_href': 'https://api.spotify.com/',
                'analysis_url': 'https://api.spotify.com/',
                'duration_ms': 0,
                'time_signature': 0
            })
        else:
            features.append({
                'song_name': track_info['name'],  # Add the song name
                'artists': ', '.join([artist['name'] for artist in track_info['artists']]),  # Add the artists as a comma-separated string
                **track  # Include the audio features
            })

      

relax_df = pd.DataFrame(features, index = track_names)
relax_df['Mood Label'] = 'relax'
relax_df.head()
# Out:
#                                                  song_name            artists  \
# Glance Out A Casement Window  Glance Out A Casement Window       Janet Redger
# This Tender Appeal                      This Tender Appeal           Allysium
# Lyrides                                            Lyrides  Jozef De Schutter
# Calm Wind                                        Calm Wind           Elfrieda
# A tale to tell                              A tale to tell      Luiza Schmidt
#
#                               danceability  energy  key  loudness  mode  \
# Glance Out A Casement Window         0.384  0.0189    1   -31.119     1
# This Tender Appeal                   0.435  0.0404    4   -26.262     1
# Lyrides                              0.297  0.0126    7   -27.760     1
# Calm Wind                            0.461  0.0286    0   -25.117     1
# A tale to tell                       0.386  0.0128    1   -28.660     1
#
# ...

# %%
#Exporting dataframe to csv
relax_df.to_csv('relax.csv',index=False)

# %%
#Fetching data from public playlist of 'upbeat' songs

sourcePlaylistID = 'https://open.spotify.com/playlist/0lU86qLkSQVI991j4BUTDF'
sourcePlaylist = sp.playlist(sourcePlaylistID)
tracks = sourcePlaylist["tracks"];
songs = tracks["items"];

track_ids = []
track_names = []

for i in range(0, len(songs)):
    if songs[i]['track']['id'] != None: # Removes the local tracks in your playlist if there is any
        track_ids.append(songs[i]['track']['id'])
        track_names.append(songs[i]['track']['name'])

features = []
for i in range(0, len(track_ids)):
    audio_features = sp.audio_features(track_ids[i])
    track_info = sp.track(track_ids[i])
    
    for track in audio_features:
        if track is None:
            print(track)
            features.append({
                'song_name': track_info['name'],  # Add the song name
                'artists': ', '.join([artist['name'] for artist in track_info['artists']]),  # Add the artists as a comma-separated string
                'danceability': 0,
                'energy': 0,
                'key': 0,
                'loudness': 0,
                'mode': 0,
                'speechiness': 0,
                'acousticness': 0,
                'instrumentalness': 0,
                'liveness': 0,
                'valence': 0,
                'tempo': 0,
                'type': 'audio_features',
                'id': '00000',
                'uri': 'spotify:track:0',
                'track_href': 'https://api.spotify.com/',
                'analysis_url': 'https://api.spotify.com/',
                'duration_ms': 0,
                'time_signature': 0
            })
        else:
            features.append({
                'song_name': track_info['name'],  # Add the song name
                'artists': ', '.join([artist['name'] for artist in track_info['artists']]),  # Add the artists as a comma-separated string
                **track  # Include the audio features
            })

      

upbeat_df = pd.DataFrame(features, index = track_names)
upbeat_df['Mood Label'] = 'upbeat'
upbeat_df.head()
# Out:
# None
#                                      song_name               artists  \
# Titanium (feat. Sia)      Titanium (feat. Sia)     David Guetta, Sia
# More Than You Know          More Than You Know    Axwell /\ Ingrosso
# I Gotta Feeling                I Gotta Feeling       Black Eyed Peas
# Waiting For Love              Waiting For Love                Avicii
# Let's Go (feat. Ne-Yo)  Let's Go (feat. Ne-Yo)  Calvin Harris, Ne-Yo
#
#                         danceability  energy  key  loudness  mode  \
# Titanium (feat. Sia)           0.604   0.787    0    -3.674     0
# More Than You Know             0.646   0.741    5    -4.973     0
# I Gotta Feeling                0.743   0.766    0    -6.375     1
# Waiting For Love               0.579   0.736    6    -3.863     0
# Let's Go (feat. Ne-Yo)         0.710   0.882    4    -2.932     0
#
#                         speechiness  acousticness  instrumentalness  ...  \
# ...

# %%
#Exporting dataframe to csv
upbeat_df.to_csv('upbeat.csv',index=False)

# %%
#Fetching data from public playlist of 'focus' songs

sourcePlaylistID = 'https://open.spotify.com/playlist/37i9dQZF1DWZeKCadgRdKQ'
sourcePlaylist = sp.playlist(sourcePlaylistID)
tracks = sourcePlaylist["tracks"];
songs = tracks["items"];

track_ids = []
track_names = []

for i in range(0, len(songs)):
    if songs[i]['track']['id'] != None: # Removes the local tracks in your playlist if there is any
        track_ids.append(songs[i]['track']['id'])
        track_names.append(songs[i]['track']['name'])

features = []
for i in range(0, len(track_ids)):
    audio_features = sp.audio_features(track_ids[i])
    track_info = sp.track(track_ids[i])
    
    for track in audio_features:
        if track is None:
            print(track)
            features.append({
                'song_name': track_info['name'],  # Add the song name
                'artists': ', '.join([artist['name'] for artist in track_info['artists']]),  # Add the artists as a comma-separated string
                'danceability': 0,
                'energy': 0,
                'key': 0,
                'loudness': 0,
                'mode': 0,
                'speechiness': 0,
                'acousticness': 0,
                'instrumentalness': 0,
                'liveness': 0,
                'valence': 0,
                'tempo': 0,
                'type': 'audio_features',
                'id': '00000',
                'uri': 'spotify:track:0',
                'track_href': 'https://api.spotify.com/',
                'analysis_url': 'https://api.spotify.com/',
                'duration_ms': 0,
                'time_signature': 0
            })
        else:
            features.append({
                'song_name': track_info['name'],  # Add the song name
                'artists': ', '.join([artist['name'] for artist in track_info['artists']]),  # Add the artists as a comma-separated string
                **track  # Include the audio features
            })

      

focus_df = pd.DataFrame(features, index = track_names)
focus_df['Mood Label'] = 'focus'
focus_df.head()
# Out:
#                            song_name      artists  danceability  energy  key  \
# Augury                        Augury     Lynx XII         0.587  0.0614    9
# emotions                    emotions  Josef Briem         0.416  0.0608    7
# Orange Sky                Orange Sky       Auðura         0.599  0.1140    4
# the echoing truth  the echoing truth  Tall Towers         0.297  0.0461    0
# So Far So Good        So Far So Good  Sun Of They         0.577  0.0721    2
#
#                    loudness  mode  speechiness  acousticness  \
# Augury              -22.387     0       0.0484         0.981
# emotions            -18.971     1       0.0410         0.961
# Orange Sky          -20.061     1       0.0399         0.966
# the echoing truth   -20.517     0       0.0336         0.910
# So Far So Good      -22.973     1       0.0317         0.981
#
#                    instrumentalness  ...  valence   tempo            type  \
# ...

# %%
#Exporting dataframe to csv
focus_df.to_csv('focus.csv',index=False)

# %%
#Fetching data from public playlist of 'romance' songs

sourcePlaylistID = 'https://open.spotify.com/playlist/37i9dQZF1DX50QitC6Oqtn'
sourcePlaylist = sp.playlist(sourcePlaylistID)
tracks = sourcePlaylist["tracks"];
songs = tracks["items"];

track_ids = []
track_names = []

for i in range(0, len(songs)):
    if songs[i]['track']['id'] != None: # Removes the local tracks in your playlist if there is any
        track_ids.append(songs[i]['track']['id'])
        track_names.append(songs[i]['track']['name'])

features = []
for i in range(0, len(track_ids)):
    audio_features = sp.audio_features(track_ids[i])
    track_info = sp.track(track_ids[i])
    
    for track in audio_features:
        if track is None:
            print(track)
            features.append({
                'song_name': track_info['name'],  # Add the song name
                'artists': ', '.join([artist['name'] for artist in track_info['artists']]),  # Add the artists as a comma-separated string
                'danceability': 0,
                'energy': 0,
                'key': 0,
                'loudness': 0,
                'mode': 0,
                'speechiness': 0,
                'acousticness': 0,
                'instrumentalness': 0,
                'liveness': 0,
                'valence': 0,
                'tempo': 0,
                'type': 'audio_features',
                'id': '00000',
                'uri': 'spotify:track:0',
                'track_href': 'https://api.spotify.com/',
                'analysis_url': 'https://api.spotify.com/',
                'duration_ms': 0,
                'time_signature': 0
            })
        else:
            features.append({
                'song_name': track_info['name'],  # Add the song name
                'artists': ', '.join([artist['name'] for artist in track_info['artists']]),  # Add the artists as a comma-separated string
                **track  # Include the audio features
            })

      

romance_df = pd.DataFrame(features, index = track_names)
romance_df['Mood Label'] = 'romance'
romance_df.head()
# Out:
#                                      song_name        artists  danceability  \
# When I Was Your Man        When I Was Your Man     Bruno Mars         0.612
# Let Me Down Slowly          Let Me Down Slowly  Alec Benjamin         0.652
# Somewhere Only We Know  Somewhere Only We Know          Keane         0.448
# Photograph                          Photograph     Ed Sheeran         0.614
# All of Me                            All of Me    John Legend         0.422
#
#                         energy  key  loudness  mode  speechiness  \
# When I Was Your Man      0.280    0    -8.648     1       0.0434
# Let Me Down Slowly       0.557    1    -5.714     0       0.0318
# Somewhere Only We Know   0.665    9    -4.203     1       0.0260
# Photograph               0.379    4   -10.480     1       0.0476
# All of Me                0.264    8    -7.064     1       0.0322
#
#                         acousticness  instrumentalness  ...  valence    tempo  \
# ...

# %%
#Exporting dataframe to csv
romance_df.to_csv('romance.csv',index=False)

# %%
#Fetching data from public playlist of 'epic' songs

sourcePlaylistID = 'https://open.spotify.com/playlist/37i9dQZF1DX76Wlfdnj7AP'
sourcePlaylist = sp.playlist(sourcePlaylistID)
tracks = sourcePlaylist["tracks"];
songs = tracks["items"];

track_ids = []
track_names = []

for i in range(0, len(songs)):
    if songs[i]['track']['id'] != None: # Removes the local tracks in your playlist if there is any
        track_ids.append(songs[i]['track']['id'])
        track_names.append(songs[i]['track']['name'])

features = []
for i in range(0, len(track_ids)):
    audio_features = sp.audio_features(track_ids[i])
    track_info = sp.track(track_ids[i])
    
    for track in audio_features:
        if track is None:
            print(track)
            features.append({
                'song_name': track_info['name'],  # Add the song name
                'artists': ', '.join([artist['name'] for artist in track_info['artists']]),  # Add the artists as a comma-separated string
                'danceability': 0,
                'energy': 0,
                'key': 0,
                'loudness': 0,
                'mode': 0,
                'speechiness': 0,
                'acousticness': 0,
                'instrumentalness': 0,
                'liveness': 0,
                'valence': 0,
                'tempo': 0,
                'type': 'audio_features',
                'id': '00000',
                'uri': 'spotify:track:0',
                'track_href': 'https://api.spotify.com/',
                'analysis_url': 'https://api.spotify.com/',
                'duration_ms': 0,
                'time_signature': 0
            })
        else:
            features.append({
                'song_name': track_info['name'],  # Add the song name
                'artists': ', '.join([artist['name'] for artist in track_info['artists']]),  # Add the artists as a comma-separated string
                **track  # Include the audio features
            })

      

epic_df = pd.DataFrame(features, index = track_names)
epic_df['Mood Label'] = 'epic'
epic_df.head()
# Out:
#                                                                    song_name  \
# MONEY                                                                  MONEY
# FE!N (feat. Playboi Carti)                        FE!N (feat. Playboi Carti)
# I'm Good (Blue)                                              I'm Good (Blue)
# Boy's a Liar Pt. 2                                        Boy's a Liar Pt. 2
# Quevedo: Bzrp Music Sessions, Vol. 52  Quevedo: Bzrp Music Sessions, Vol. 52
#
#                                                            artists  \
# MONEY                                                         LISA
# FE!N (feat. Playboi Carti)             Travis Scott, Playboi Carti
# I'm Good (Blue)                           David Guetta, Bebe Rexha
# Boy's a Liar Pt. 2                       PinkPantheress, Ice Spice
# Quevedo: Bzrp Music Sessions, Vol. 52            Bizarrap, Quevedo
#
#                                        danceability  energy  key  loudness  \
# ...

# %%
#Exporting dataframe to csv
epic_df.to_csv('epic.csv',index=False)

# %%
#Fetching data from public playlist of 'tranquil' songs

sourcePlaylistID = 'https://open.spotify.com/playlist/37i9dQZF1DX4FLflF8wPKE'
sourcePlaylist = sp.playlist(sourcePlaylistID)
tracks = sourcePlaylist["tracks"];
songs = tracks["items"];

track_ids = []
track_names = []

for i in range(0, len(songs)):
    if songs[i]['track']['id'] != None: # Removes the local tracks in your playlist if there is any
        track_ids.append(songs[i]['track']['id'])
        track_names.append(songs[i]['track']['name'])

features = []
for i in range(0, len(track_ids)):
    audio_features = sp.audio_features(track_ids[i])
    track_info = sp.track(track_ids[i])
    
    for track in audio_features:
        if track is None:
            print(track)
            features.append({
                'song_name': track_info['name'],  # Add the song name
                'artists': ', '.join([artist['name'] for artist in track_info['artists']]),  # Add the artists as a comma-separated string
                'danceability': 0,
                'energy': 0,
                'key': 0,
                'loudness': 0,
                'mode': 0,
                'speechiness': 0,
                'acousticness': 0,
                'instrumentalness': 0,
                'liveness': 0,
                'valence': 0,
                'tempo': 0,
                'type': 'audio_features',
                'id': '00000',
                'uri': 'spotify:track:0',
                'track_href': 'https://api.spotify.com/',
                'analysis_url': 'https://api.spotify.com/',
                'duration_ms': 0,
                'time_signature': 0
            })
        else:
            features.append({
                'song_name': track_info['name'],  # Add the song name
                'artists': ', '.join([artist['name'] for artist in track_info['artists']]),  # Add the artists as a comma-separated string
                **track  # Include the audio features
            })

      

tranquil_df = pd.DataFrame(features, index = track_names)
tranquil_df['Mood Label'] = 'tranquil'
tranquil_df.head()
# Out:
#                                      song_name  \
# Circle                                  Circle
# Violet Sunset                    Violet Sunset
# Something from Nothing  Something from Nothing
# Billow Gently                    Billow Gently
# Sauntering Dream              Sauntering Dream
#
#                                                   artists  danceability  \
# Circle                                        Phil France         0.388
# Violet Sunset                                Arnold Kasar         0.283
# Something from Nothing                    Pieter de Graaf         0.299
# Billow Gently            Sophie Hutchings, Lavinia Meijer         0.292
# Sauntering Dream        We Dream of Eden, Jonathan Warman         0.172
#
#                         energy  key  loudness  mode  speechiness  \
# Circle                  0.2230    6   -15.605     1       0.0356
# Violet Sunset           0.1210    1   -18.147     1       0.0301
# ...

# %%
#Exporting dataframe to csv
tranquil_df.to_csv('tranquil.csv',index=False)

# %%
#Fetching data from public playlist of 'ambient' songs

sourcePlaylistID = 'https://open.spotify.com/playlist/37i9dQZF1DX5y2yPmGqrG8'
sourcePlaylist = sp.playlist(sourcePlaylistID)
tracks = sourcePlaylist["tracks"];
songs = tracks["items"];

track_ids = []
track_names = []

for i in range(0, len(songs)):
    if songs[i]['track']['id'] != None: # Removes the local tracks in your playlist if there is any
        track_ids.append(songs[i]['track']['id'])
        track_names.append(songs[i]['track']['name'])

features = []
for i in range(0, len(track_ids)):
    audio_features = sp.audio_features(track_ids[i])
    track_info = sp.track(track_ids[i])
    
    for track in audio_features:
        if track is None:
            print(track)
            features.append({
                'song_name': track_info['name'],  # Add the song name
                'artists': ', '.join([artist['name'] for artist in track_info['artists']]),  # Add the artists as a comma-separated string
                'danceability': 0,
                'energy': 0,
                'key': 0,
                'loudness': 0,
                'mode': 0,
                'speechiness': 0,
                'acousticness': 0,
                'instrumentalness': 0,
                'liveness': 0,
                'valence': 0,
                'tempo': 0,
                'type': 'audio_features',
                'id': '00000',
                'uri': 'spotify:track:0',
                'track_href': 'https://api.spotify.com/',
                'analysis_url': 'https://api.spotify.com/',
                'duration_ms': 0,
                'time_signature': 0
            })
        else:
            features.append({
                'song_name': track_info['name'],  # Add the song name
                'artists': ', '.join([artist['name'] for artist in track_info['artists']]),  # Add the artists as a comma-separated string
                **track  # Include the audio features
            })

      

ambient_df = pd.DataFrame(features, index = track_names)
ambient_df['Mood Label'] = 'ambient'
ambient_df.head()
# Out:
#                    song_name                  artists  danceability   energy  \
# Comfort Chain  Comfort Chain               Instupendo         0.830  0.25100
# Present              Present               Lloyd Vaan         0.227  0.00268
# #3                        #3               Aphex Twin         0.159  0.07100
# Enough                Enough  Fred again.., Brian Eno         0.150  0.20800
# setar rock        setar rock                    Maral         0.804  0.32500
#
#                key  loudness  mode  speechiness  acousticness  \
# Comfort Chain    4   -19.774     1       0.0779         0.980
# Present          3   -27.348     1       0.0600         0.951
# #3               6   -27.109     0       0.0409         0.911
# Enough          10   -16.901     1       0.0409         0.936
# setar rock       2   -13.067     1       0.0469         0.601
#
#                instrumentalness  ...  valence    tempo            type  \
# ...

# %%
#Exporting dataframe to csv
ambient_df.to_csv('ambient.csv',index=False)

# %%
#Fetching data from public playlist of 'enigmatic' songs

sourcePlaylistID = 'https://open.spotify.com/playlist/37i9dQZF1DX1tz6EDao8it'
sourcePlaylist = sp.playlist(sourcePlaylistID)
tracks = sourcePlaylist["tracks"];
songs = tracks["items"];

track_ids = []
track_names = []

for i in range(0, len(songs)):
    if songs[i]['track']['id'] != None: # Removes the local tracks in your playlist if there is any
        track_ids.append(songs[i]['track']['id'])
        track_names.append(songs[i]['track']['name'])

features = []
for i in range(0, len(track_ids)):
    audio_features = sp.audio_features(track_ids[i])
    track_info = sp.track(track_ids[i])
    
    for track in audio_features:
        if track is None:
            print(track)
            features.append({
                'song_name': track_info['name'],  # Add the song name
                'artists': ', '.join([artist['name'] for artist in track_info['artists']]),  # Add the artists as a comma-separated string
                'danceability': 0,
                'energy': 0,
                'key': 0,
                'loudness': 0,
                'mode': 0,
                'speechiness': 0,
                'acousticness': 0,
                'instrumentalness': 0,
                'liveness': 0,
                'valence': 0,
                'tempo': 0,
                'type': 'audio_features',
                'id': '00000',
                'uri': 'spotify:track:0',
                'track_href': 'https://api.spotify.com/',
                'analysis_url': 'https://api.spotify.com/',
                'duration_ms': 0,
                'time_signature': 0
            })
        else:
            features.append({
                'song_name': track_info['name'],  # Add the song name
                'artists': ', '.join([artist['name'] for artist in track_info['artists']]),  # Add the artists as a comma-separated string
                **track  # Include the audio features
            })

      

enigmatic_df = pd.DataFrame(features, index = track_names)
enigmatic_df['Mood Label'] = 'enigmatic'
enigmatic_df.head()
# Out:
#                                                                                             song_name  \
# He's a Pirate (from "Pirates of the Caribbean: ...  He's a Pirate (from "Pirates of the Caribbean:...
# Time                                                                                             Time
# Theme From Jurassic Park                                                     Theme From Jurassic Park
# Cornfield Chase                                                                       Cornfield Chase
# Comptine d'un autre été, l'après-midi                           Comptine d'un autre été, l'après-midi
#
#                                                           artists  \
# He's a Pirate (from "Pirates of the Caribbean: ...   Klaus Badelt
# Time                                                  Hans Zimmer
# Theme From Jurassic Park                            John Williams
# Cornfield Chase                                       Hans Zimmer
# ...

# %%
#Exporting dataframe to csv
enigmatic_df.to_csv('enigmatic.csv',index=False)
